# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar tus 3 archivos (ajusta los nombres)
consumo = pd.read_csv('../data/raw/consumo_esios_2023.csv', sep=';')
precios = pd.read_csv('../data/raw/precios_esios_2023.csv', sep=';')
solar = pd.read_csv('../data/raw/solar_pvgis_2023.csv', skiprows=10)

# Pintar las primeras 24 horas para ver si tiene buena pinta
plt.figure(figsize=(15, 5))
plt.plot(consumo.iloc[:24, 2], label='Consumo (Coeficiente)')
plt.title("Prueba de Consumo")
plt.show()
